# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
 
A = cv2.imread('training/real1.jpg')
plt.imshow(A)

# %%
a = cv2.cvtColor(A, cv2.COLOR_BGR2GRAY)
plt.imshow(a)

# %%
a2tr = a[140:340, 150:350]
plt.imshow(a2tr)

# %%
print(a.shape)
a2_str = a[123:340, 350:370]
plt.imshow(a2_str)
# Out:
# (383, 624)

# %%
hsvImageReal = cv2.cvtColor(A, cv2.COLOR_BGR2HSV)

# %%
plt.imshow(hsvImageReal)
