# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
 
A = cv2.imread('training/fake.jpeg')
plt.imshow(A)

# %%
a = cv2.cvtColor(A, cv2.COLOR_BGR2GRAY)
plt.imshow(a)

# %%
a2tr = a[27:125, 80:188]
plt.imshow(a2tr)

# %%
print(a.shape)
a2_str = a[22:140, 188:195]
plt.imshow(a2_str)
# Out:
# (149, 337)

# %%
hsvImageReal = cv2.cvtColor(A, cv2.COLOR_BGR2HSV)

# %%
plt.imshow(hsvImageReal)
